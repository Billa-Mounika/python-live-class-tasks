# %%
import pandas as pd
df = pd.read_csv('C:/Users/bmounika/Desktop/DS1/Ineuron/Python/Ineuron-Assignments/Python_Live_Class_Tasks/bank_task/bank-full.csv',sep=';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#1 . how many campaign available in this dataset . 
 
len(df['campaign'].unique())
# Out:
# 48

# %%
#2 . how many users do we have with housing and personal loan .
len(df[(df['housing'] == 'yes') & (df['loan'] == 'yes')])
# Out:
# 4367

# %%
#3. how many person do we have whose age is 60+ . 
len(df[df['age'] > 60])
# Out:
# 1188

# %%
#4 . in which month we have trageted most of the customer . 
df['month'].value_counts().index[0]
# Out:
# 'may'

# %%
#5 . which mode of call is giving you more result.
df_groupby = df.groupby(['contact','y']).count()
df.groupby(['contact','y']).count()
# Out:
#                  age    job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   24916  24916    24916      24916    24916    24916    24916
#           yes   4369   4369     4369       4369     4369     4369     4369
# telephone no    2516   2516     2516       2516     2516     2516     2516
#           yes    390    390      390        390      390      390      390
# unknown   no   12490  12490    12490      12490    12490    12490    12490
#           yes    530    530      530        530      530      530      530
#
#                 loan    day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   24916  24916  24916     24916     24916  24916     24916
#           yes   4369   4369   4369      4369      4369   4369      4369
# telephone no    2516   2516   2516      2516      2516   2516      2516
#           yes    390    390    390       390       390    390       390
# ...

# %%
max(df_groupby.loc['cellular','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0])
# Out:
# 4369

# %%
#6 . how many enterpeures do we have in this list
len(df[df['job'] == 'entrepreneur'])
# Out:
# 1487

# %%
#7 . how many customers do we have with negative balance 
len(df[df['balance'] < 0])
# Out:
# 3766

# %%
#8. prepare a group of data based on education level . 
df.groupby('education')['education'].count()

#or
# Out:
# education
# primary       6851
# secondary    23202
# tertiary     13301
# unknown       1857
# Name: education, dtype: int64

# %%
df['education'].value_counts()

#or
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
l=[]
for i in df['education'].unique():
    l.append(df[df['education'] == i])

# %%
len(l)
# Out:
# 4

# %%
l[0] # for tertiary
# Out:
#        age           job   marital education default  balance housing loan  \
# 0       58    management   married  tertiary      no     2143     yes   no
# 5       35    management   married  tertiary      no      231     yes   no
# 6       28    management    single  tertiary      no      447     yes  yes
# 7       42  entrepreneur  divorced  tertiary     yes        2     yes   no
# 21      56    management   married  tertiary      no      779     yes   no
# ...    ...           ...       ...       ...     ...      ...     ...  ...
# 45194   59    management   married  tertiary      no      138     yes  yes
# 45198   37    management   married  tertiary      no     1428      no   no
# 45201   53    management   married  tertiary      no      583      no   no
# 45203   23       student    single  tertiary      no      113      no   no
# 45206   51    technician   married  tertiary      no      825      no   no
#
# ...

# %%
l[1] # for secondary
# Out:
#        age           job   marital  education default  balance housing loan  \
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 9       43    technician    single  secondary      no      593     yes   no
# 10      41        admin.  divorced  secondary      no      270     yes   no
# 11      29        admin.    single  secondary      no      390     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45204   73       retired   married  secondary      no     2850      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
l[2] # for unknown
# Out:
#        age          job  marital education default  balance housing loan  \
# 3       47  blue-collar  married   unknown      no     1506     yes   no
# 4       33      unknown   single   unknown      no        1      no   no
# 13      58   technician  married   unknown      no       71     yes   no
# 16      45       admin.   single   unknown      no       13     yes   no
# 42      60  blue-collar  married   unknown      no      104     yes   no
# ...    ...          ...      ...       ...     ...      ...     ...  ...
# 45129   46   technician  married   unknown      no     3308      no   no
# 45141   77      unknown  married   unknown      no      397      no   no
# 45150   65   management  married   unknown      no     2352      no   no
# 45158   34      student   single   unknown      no     2321      no   no
# 45186   59      unknown  married   unknown      no     1500      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
l[3] # for primary
# Out:
#        age          job   marital education default  balance housing loan  \
# 8       58      retired   married   primary      no      121     yes   no
# 15      51      retired   married   primary      no      229     yes   no
# 17      57  blue-collar   married   primary      no       52     yes   no
# 18      60      retired   married   primary      no       60     yes   no
# 22      32  blue-collar    single   primary      no       23     yes  yes
# ...    ...          ...       ...       ...     ...      ...     ...  ...
# 45152   61    housemaid   married   primary      no      182      no   no
# 45154   63      retired   married   primary      no     3738      no   no
# 45170   19      student    single   primary      no      245      no   no
# 45183   70      retired   married   primary      no      324      no   no
# 45207   71      retired  divorced   primary      no     1729      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
